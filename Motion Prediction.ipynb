# %% [markdown]
# # Motion prediction testing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('out.txt')
data.head(5)
# Out:
#           x         y        kx        ky       kvx       kvy
# 0  0.230925  0.240611  0.180845  0.231728  0.061055  1.034761
# 1  0.230847  0.240599  0.202932  0.238218  0.066187  1.051168
# 2  0.228689  0.240544  0.215749  0.249501  0.068759  0.182333
# 3  0.228682  0.239091  0.224397  0.242137  0.070580 -0.020710
# 4  0.228716  0.239503  0.230659  0.239553  0.069147 -0.024775

# %%
plt.plot(data.x)

# %%
plt.plot(data.kx)

# %%
plt.plot(data.kvx)
