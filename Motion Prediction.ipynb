# %% [markdown]
# # Motion prediction testing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('out.txt')
data.head(5)
# Out:
#           x         y        kx        ky       kvx       kvy
# 0  0.224621  0.200987  0.224599  0.200968  0.042767  0.038268
# 1  0.224902  0.200587  0.224933  0.200619  0.002710 -0.002369
# 2  0.224467  0.202223  0.224627  0.201825 -0.000308  0.005153
# 3  0.226126  0.200324  0.225620  0.200992  0.003918 -0.000425
# 4  0.226128  0.199845  0.226134  0.200228  0.003877 -0.002839

# %%
plt.plot(data.x)

# %%
plt.plot(data.kx)

# %%
plt.plot(data.kvx)

# %% [markdown]
# ## Y Data

# %%
plt.plot(data.y, label='x')
plt.plot(data.ky, label='kalman x')
plt.title('y position')
plt.legend()

# %%
plt.plot(data.kvy)
plt.title('y velocity')
# Out:
# Text(0.5, 1.0, 'y velocity')
