# %% [markdown]
# # Motion prediction testing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('out.txt')
data.head(5)
# Out:
#           x         y        kx        ky       kvx       kvy
# 0  0.230274  0.303677  0.230186  0.303561  0.048061  0.063381
# 1  0.230453  0.303431  0.230627  0.303678  0.006147  0.003661
# 2  0.231335  0.299166  0.231318  0.300025  0.006605 -0.020431
# 3  0.233172  0.295965  0.232815  0.296568  0.010311 -0.026694
# 4  0.234045  0.298569  0.234247  0.296794  0.008282 -0.008824

# %%
plt.plot(data.x)

# %%
plt.plot(data.kx)

# %%
plt.plot(data.kvx)

# %% [markdown]
# ## Y Data

# %%
plt.plot(data.y, label='x')
plt.plot(data.ky, label='kalman x')
plt.title('y position')
plt.legend()

# %%
plt.plot(data.kvy)
plt.title('y velocity')
# Out:
# Text(0.5, 1.0, 'y velocity')
